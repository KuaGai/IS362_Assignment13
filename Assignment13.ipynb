# %% [markdown]
# Assignment13
#
# Importing the necessary libraries:

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Putting data in frame and add columns:

# %%
shrooms = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/mushroom/agaricus-lepiota.data',sep=',', header=None, usecols=[0,3,5], names=["Edible","Color","Odor"])
shrooms
# Out:
#      Edible Color Odor
# 0         p     n    p
# 1         e     y    a
# 2         e     w    l
# 3         p     w    p
# 4         e     g    n
# 5         e     y    a
# 6         e     w    a
# 7         e     w    l
# 8         p     w    p
# 9         e     y    a
# 10        e     y    l
# 11        e     y    a
# 12        e     y    a
# 13        p     w    p
# 14        e     n    n
# 15        e     g    n
# 16        e     w    n
# 17        p     n    p
# 18        p     w    p
# 19        p     n    p
# 20        e     y    a
# 21        p     n    p
# 22        e     y    l
# 23        e     w    a
# 24        e     w    l
# 25        p     w    p
# 26        e     y    a
# 27        e     w    l
# 28        e     n    n
# 29        e     y    a
# ...     ...   ...  ...
# 8094      e     g    n
# 8095      p     c    m
# 8096      e     w    n
# 8097      p     n    s
# 8098      p     e    y
# 8099      e     w    n
# 8100      e     n    n
# 8101      p     e    s
# 8102      e     n    n
# 8103      e     n    n
# 8104      e     n    n
# 8105      e     n    n
# 8106      e     n    n
# 8107      e     n    n
# 8108      p     e    y
# 8109      e     w    n
# 8110      e     n    n
# 8111      e     w    n
# 8112      e     n    n
# 8113      p     e    y
# 8114      p     c    m
# 8115      e     n    n
# 8116      p     n    s
# 8117      p     e    y
# 8118      p     n    f
# 8119      e     n    n
# 8120      e     n    n
# 8121      e     n    n
# 8122      p     n    y
# 8123      e     n    n
#
# [8124 rows x 3 columns]

# %% [markdown]
# Change the code to more readable data.
#
# Edible:
#
# Poisonous = p = 1
# Edible = e = 0
#
# Color:
#
# brown = n = 0
# buff = b = 1
# cinnamon = c = 2
# gray = g = 3
# green = r = 4
# pink = p = 5
# purple = u = 6
# red = e = 7
# white = w = 8
# yellow = y = 9
#
# Odor:
# almond = a = 0
# anise = l = 1
# creosote = c = 2
# fishy = y = 3
# foul = f = 4
# musty = m = 5
# none = n = 6
# pungent = p = 7
# spicy = s = 8

# %%
shrooms.replace(to_replace={"Edible":{'p': 1, 'e': 0}}, inplace=True)
shrooms.replace(to_replace={'Color':{'n':0, 'b':1, 'c':2, 'g':3, 'r':4, 'p':5, 'u':6, 'e':7, 'w':8, 'y':9}}, inplace=True)
shrooms.replace(to_replace={'Odor':{'a':0, 'l':1, 'c':2, 'y':3, 'f':4, 'm':5, 'n':6, 'p':7, 's':8}}, inplace=True)

# %%
shrooms
# Out:
#       Edible  Color  Odor
# 0          1      0     7
# 1          0      9     0
# 2          0      8     1
# 3          1      8     7
# 4          0      3     6
# 5          0      9     0
# 6          0      8     0
# 7          0      8     1
# 8          1      8     7
# 9          0      9     0
# 10         0      9     1
# 11         0      9     0
# 12         0      9     0
# 13         1      8     7
# 14         0      0     6
# 15         0      3     6
# 16         0      8     6
# 17         1      0     7
# 18         1      8     7
# 19         1      0     7
# 20         0      9     0
# 21         1      0     7
# 22         0      9     1
# 23         0      8     0
# 24         0      8     1
# 25         1      8     7
# 26         0      9     0
# 27         0      8     1
# 28         0      0     6
# 29         0      9     0
# ...      ...    ...   ...
# 8094       0      3     6
# 8095       1      2     5
# 8096       0      8     6
# 8097       1      0     8
# 8098       1      7     3
# 8099       0      8     6
# 8100       0      0     6
# 8101       1      7     8
# 8102       0      0     6
# 8103       0      0     6
# 8104       0      0     6
# 8105       0      0     6
# 8106       0      0     6
# 8107       0      0     6
# 8108       1      7     3
# 8109       0      8     6
# 8110       0      0     6
# 8111       0      8     6
# 8112       0      0     6
# 8113       1      7     3
# 8114       1      2     5
# 8115       0      0     6
# 8116       1      0     8
# 8117       1      7     3
# 8118       1      0     4
# 8119       0      0     6
# 8120       0      0     6
# 8121       0      0     6
# 8122       1      0     3
# 8123       0      0     6
#
# [8124 rows x 3 columns]

# %% [markdown]
# Analysing the data and preseting in a graph.

# %%
sns.set(style="ticks", context="talk")
pal = sns.color_palette("hls", 8)
g = sns.lmplot(x='Odor', y='Color', hue='Edible', data=shrooms, palette=pal, size=7)
g.set_axis_labels("Odor", "Color")
plt.show()

# %% [markdown]
# The data in the graph shows wich mushrom can be eaten and which not. Most of the mushrooms will **kill** you, except for mushrooms with no odor and the colors of cinnamon, grey, green, purple and red.
